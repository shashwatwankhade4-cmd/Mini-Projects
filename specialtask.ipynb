# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("info.csv")

# %%
print("First 5 rows of the dataset:")
print(df.head())

print("Last 5 rows of the dataset:")
print(df.tail())

print("Shape of the dataset:")
print(df.shape)

print("Column names:")
print(df.columns)

print("Dataset information:")
print(df.info())

print("Summary statistics:")
print(df.describe())

print("Data types:")
print(df.dtypes)

print("Missing values:")
print(df.isnull().sum())

print("Unique values:")
print(df.nunique())

print("Random 5 rows:")
print(df.sample(5))
# Out:
# First 5 rows of the dataset:
#        File No        Team 1  Team 1 Runs  Team 1 Wickets     Team 2  \
# 0   710305.csv    Bangladesh          326               3   Pakistan
# 1   667889.csv       England          247               6  Sri Lanka
# 2  1073420.csv      Pakistan           91              10   Scotland
# 3   749547.csv        Jersey          185              10       Oman
# 4   463154.csv  South Africa          250               9      India
#
#    Team 2 Runs  Team 2 Wickets  Gender   Season        Date  ...  \
# 0          329               7    male  2013/14  2014/03/04  ...
# 1          144              10    male     2014  2014/05/22  ...
# 2           94               4  female  2016/17  2017/02/13  ...
# 3          189               3    male     2014  2014/06/22  ...
# 4          234              10    male  2010/11  2011/01/23  ...
#
#              Umpire 1       Umpire 2    Reserve Umpire  TV Umpire  \
# 0           JD Cloete       NJ Llong      Tanvir Ahmed  CK Nandan
# 1           RJ Bailey    CB Gaffaney       RT Robinson  M Erasmus
# 2         JM Williams  RR Wimalasiri  RMPJ Rambukwella        NaN
# 3  Ahmed Shah Durrani       C Howard        N Morrison        NaN
# 4          BG Jerling     SJA Taufel         JD Cloete   S George
#
#   Match Referee        Winner Outcome Winner Runs Winner Wickets Method
# 0      BC Broad      Pakistan     NaN         NaN            3.0    NaN
# 1      JJ Crowe       England     NaN        81.0            NaN    D/L
# 2           NaN      Pakistan     NaN         NaN            6.0    NaN
# 3    SR Bernard          Oman     NaN         NaN            7.0    NaN
# 4      BC Broad  South Africa     NaN        33.0            NaN    D/L
#
# [5 rows x 29 columns]
# Last 5 rows of the dataset:
#          File No        Team 1  Team 1 Runs  Team 1 Wickets     Team 2  \
# 1664  236358.csv     Australia          274               8  Sri Lanka
# 1665  520593.csv   New Zealand          372               6   Zimbabwe
# 1666  247476.csv         India          254               6  Sri Lanka
# 1667  387567.csv  South Africa          354               6    England
# 1668  238188.csv         India          203              10    England
#
#       Team 2 Runs  Team 2 Wickets Gender   Season        Date  ...   Umpire 1  \
# 1664          252              10   male  2005/06  2006/02/10  ...  Aleem Dar
# 1665          231               8   male  2011/12  2012/02/06  ...    AL Hill
# 1666          185              10   male  2006/07  2007/03/23  ...  Aleem Dar
# 1667          242              10   male  2009/10  2009/11/27  ...  M Erasmus
# 1668          164              10   male  2005/06  2006/03/28  ...  Asad Rauf
#
#             Umpire 2  Reserve Umpire     TV Umpire Match Referee  \
# 1664       DJ Harper             NaN      RL Parry      JJ Crowe
# 1665       RJ Tucker        BG Frost  Enamul Haque       DC Boon
# 1666       DJ Harper       IL Howell      SJ Davis      JJ Crowe
# 1667       RJ Tucker       JD Cloete    BG Jerling     J Srinath
# 1668  AV Jayaprakash             NaN   K Hariharan   RS Mahanama
#
#             Winner Outcome Winner Runs Winner Wickets Method
# 1664     Sri Lanka     NaN        22.0            NaN    NaN
# 1665   New Zealand     NaN       141.0            NaN    NaN
# 1666     Sri Lanka     NaN        69.0            NaN    NaN
# 1667  South Africa     NaN       112.0            NaN    NaN
# 1668         India     NaN        39.0            NaN    NaN
#
# [5 rows x 29 columns]
# Shape of the dataset:
# (1669, 29)
# Column names:
# Index(['File No', 'Team 1', 'Team 1 Runs', 'Team 1 Wickets', 'Team 2',
#        'Team 2 Runs', 'Team 2 Wickets', 'Gender', 'Season', 'Date', 'Series',
#        'Competition', 'Match Number', 'Venue', 'City', 'Neutral Venue',
#        'Toss Winner', 'Toss Decision', 'Player of Match', 'Umpire 1',
#        'Umpire 2', 'Reserve Umpire', 'TV Umpire', 'Match Referee', 'Winner',
#        'Outcome', 'Winner Runs', 'Winner Wickets', 'Method'],
#       dtype='str')
# Dataset information:
# <class 'pandas.DataFrame'>
# RangeIndex: 1669 entries, 0 to 1668
# Data columns (total 29 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   File No          1669 non-null   str
#  1   Team 1           1669 non-null   str
#  2   Team 1 Runs      1669 non-null   int64
#  3   Team 1 Wickets   1669 non-null   int64
#  4   Team 2           1669 non-null   str
#  5   Team 2 Runs      1669 non-null   int64
#  6   Team 2 Wickets   1669 non-null   int64
#  7   Gender           1669 non-null   str
#  8   Season           1669 non-null   str
#  9   Date             1669 non-null   str
#  10  Series           1030 non-null   str
#  11  Competition      664 non-null    str
#  12  Match Number     1477 non-null   float64
#  13  Venue            1669 non-null   str
#  14  City             1414 non-null   str
#  15  Neutral Venue    466 non-null    object
#  16  Toss Winner      1669 non-null   str
#  17  Toss Decision    1669 non-null   str
#  18  Player of Match  1562 non-null   str
#  19  Umpire 1         1669 non-null   str
#  20  Umpire 2         1669 non-null   str
#  21  Reserve Umpire   1527 non-null   str
#  22  TV Umpire        1292 non-null   str
#  23  Match Referee    1635 non-null   str
#  24  Winner           1630 non-null   str
#  25  Outcome          39 non-null     str
#  26  Winner Runs      808 non-null    float64
#  27  Winner Wickets   822 non-null    float64
#  28  Method           156 non-null    str
# dtypes: float64(3), int64(4), object(1), str(21)
# memory usage: 378.3+ KB
# None
# Summary statistics:
#        Team 1 Runs  Team 1 Wickets  Team 2 Runs  Team 2 Wickets  Match Number  \
# count  1669.000000     1669.000000  1669.000000     1669.000000   1477.000000
# mean    243.596165        8.033553   201.977232        6.759137      6.454976
# std      65.012542        1.949008    62.937939        3.184492      8.781920
# min      67.000000        1.000000     0.000000        0.000000      1.000000
# 25%     202.000000        7.000000   159.000000        4.000000      2.000000
# 50%     246.000000        8.000000   206.000000        7.000000      3.000000
# 75%     288.000000       10.000000   246.000000       10.000000      5.000000
# max     444.000000       10.000000   411.000000       10.000000     51.000000
#
#        Winner Runs  Winner Wickets
# count   808.000000      822.000000
# mean     74.845297        5.643552
# std      56.688432        2.208543
# min       1.000000        1.000000
# 25%      29.000000        4.000000
# 50%      63.000000        6.000000
# 75%     109.250000        7.000000
# max     300.000000       10.000000
# Data types:
# File No                str
# Team 1                 str
# Team 1 Runs          int64
# Team 1 Wickets       int64
# Team 2                 str
# Team 2 Runs          int64
# Team 2 Wickets       int64
# Gender                 str
# Season                 str
# Date                   str
# Series                 str
# Competition            str
# Match Number       float64
# Venue                  str
# City                   str
# Neutral Venue       object
# Toss Winner            str
# Toss Decision          str
# Player of Match        str
# Umpire 1               str
# Umpire 2               str
# Reserve Umpire         str
# TV Umpire              str
# Match Referee          str
# Winner                 str
# Outcome                str
# Winner Runs        float64
# Winner Wickets     float64
# Method                 str
# dtype: object
# Missing values:
# File No               0
# Team 1                0
# Team 1 Runs           0
# Team 1 Wickets        0
# Team 2                0
# Team 2 Runs           0
# Team 2 Wickets        0
# Gender                0
# Season                0
# Date                  0
# Series              639
# Competition        1005
# Match Number        192
# Venue                 0
# City                255
# Neutral Venue      1203
# Toss Winner           0
# Toss Decision         0
# Player of Match     107
# Umpire 1              0
# Umpire 2              0
# Reserve Umpire      142
# TV Umpire           377
# Match Referee        34
# Winner               39
# Outcome            1630
# Winner Runs         861
# Winner Wickets      847
# Method             1513
# dtype: int64
# Unique values:
# File No            1669
# Team 1               48
# Team 1 Runs         308
# Team 1 Wickets       10
# Team 2               49
# Team 2 Runs         290
# Team 2 Wickets       11
# Gender                2
# Season               25
# Date               1317
# Series              154
# Competition          37
# Match Number         49
# Venue               205
# City                137
# Neutral Venue         1
# Toss Winner          52
# Toss Decision         2
# Player of Match     554
# Umpire 1            172
# Umpire 2            174
# Reserve Umpire      311
# TV Umpire           115
# Match Referee        43
# Winner               49
# Outcome               2
# Winner Runs         202
# Winner Wickets       10
# Method                1
# dtype: int64
# Random 5 rows:
#          File No        Team 1  Team 1 Runs  Team 1 Wickets     Team 2  \
# 794   518963.csv         India          289               6  Sri Lanka
# 1356  473928.csv   New Zealand          311               7   Pakistan
# 141   685731.csv  South Africa          218               9   Pakistan
# 965   531631.csv       England          260               7   Pakistan
# 836   952199.csv         Nepal          239               9    Namibia
#
#       Team 2 Runs  Team 2 Wickets Gender   Season        Date  ...  \
# 794           238              10   male  2011/12  2012/02/21  ...
# 1356          254              10   male  2010/11  2011/02/05  ...
# 141           195              10   male  2013/14  2013/11/24  ...
# 965           130              10   male  2011/12  2012/02/13  ...
# 836           240               7   male  2015/16  2016/04/18  ...
#
#         Umpire 1      Umpire 2  Reserve Umpire        TV Umpire Match Referee  \
# 794    BF Bowden    PR Reiffel    BNJ Oxenford         SJ Davis      BC Broad
# 1356    SJ Davis       AL Hill      WR Knights        BF Bowden      AG Hurst
# 141    JD Cloete   CB Gaffaney        S George     BNJ Oxenford      BC Broad
# 965   Ahsan Raza    SJA Taufel   Zameer Haider  HDPK Dharmasena      JJ Crowe
# 836   BB Pradhan  Sharfuddoula          VK Jha              NaN    GF Labrooy
#
#            Winner Outcome Winner Runs Winner Wickets Method
# 794     Sri Lanka     NaN        51.0            NaN    NaN
# 1356  New Zealand     NaN        57.0            NaN    NaN
# 141      Pakistan     NaN        23.0            NaN    NaN
# 965       England     NaN       130.0            NaN    NaN
# 836         Nepal     NaN         NaN            3.0    NaN
#
# [5 rows x 29 columns]
